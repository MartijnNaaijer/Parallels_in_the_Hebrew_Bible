# %%
import sys, os, csv, collections, time

# %%
from tf.fabric import Fabric

DATABASE = '~/github'
BHSA = 'bhsa/tf/c'

TF = Fabric(locations=[DATABASE], modules=[BHSA], silent=False )
# Out:
# This is Text-Fabric 3.0.3
# Api reference : https://github.com/Dans-labs/text-fabric/wiki/Api
# Tutorial      : https://github.com/Dans-labs/text-fabric/blob/master/docs/tutorial.ipynb
# Example data  : https://github.com/Dans-labs/text-fabric-data
#
# 107 features found and 0 ignored

# %%
api = TF.load('''
    otype
    lex
''')
# Out:
#   0.00s loading features ...
#    |     0.06s B otype                from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.10s B lex                  from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.00s Feature overview: 102 for nodes; 4 for edges; 1 configs; 7 computed
#   4.03s All features loaded/computed - for details use loadLog()

# %%
api.loadLog()
api.makeAvailableIn(globals())
# Out:
#    |     0.00s M otext                from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.06s B otype                from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.49s B oslots               from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.00s M otext                from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.01s B book                 from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.01s B chapter              from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.01s B verse                from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.14s B g_cons               from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.18s B g_cons_utf8          from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.14s B g_lex                from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.19s B g_lex_utf8           from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.12s B g_word               from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.16s B g_word_utf8          from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.10s B lex0                 from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.15s B lex_utf8             from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.00s B qere                 from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.00s B qere_trailer         from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.00s B qere_trailer_utf8    from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.00s B qere_utf8            from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.06s B trailer              from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.07s B trailer_utf8         from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.00s B __levels__           from otype, oslots
#    |     0.04s B __order__            from otype, oslots, __levels__
#    |     0.04s B __rank__             from otype, __order__
#    |     0.83s B __levUp__            from otype, oslots, __rank__
#    |     0.74s B __levDown__          from otype, __levUp__, __rank__
#    |     0.27s B __boundary__         from otype, oslots, __rank__
#    |     0.01s B __sections__         from otype, oslots, otext, __levUp__, __levels__, book, chapter, verse
#    |     0.10s B lex                  from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.00s B book@am              from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.00s B book@ar              from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.00s B book@bn              from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.00s B book@da              from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.00s B book@de              from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.00s B book@el              from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.00s B book@en              from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.00s B book@es              from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.00s B book@fa              from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.00s B book@fr              from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.00s B book@he              from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.00s B book@hi              from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.00s B book@id              from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.00s B book@ja              from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.00s B book@ko              from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.00s B book@la              from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.00s B book@nl              from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.00s B book@pa              from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.00s B book@pt              from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.00s B book@ru              from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.00s B book@sw              from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.00s B book@syc             from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.00s B book@tr              from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.00s B book@ur              from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.00s B book@yo              from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.00s B book@zh              from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.00s M code                 from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.00s M det                  from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.00s M dist                 from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.00s M dist_unit            from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.00s M distributional_parent from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.00s M domain               from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.00s M freq_lex             from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.00s M freq_occ             from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.00s M function             from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.00s M functional_parent    from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.00s M g_nme                from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.00s M g_nme_utf8           from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.00s M g_pfm                from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.00s M g_pfm_utf8           from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.00s M g_prs                from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.00s M g_prs_utf8           from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.00s M g_uvf                from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.00s M g_uvf_utf8           from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.00s M g_vbe                from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.00s M g_vbe_utf8           from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.00s M g_vbs                from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.00s M g_vbs_utf8           from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.00s M gloss                from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.00s M gn                   from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.00s M instruction          from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.00s M is_root              from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.00s M kind                 from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.00s M label                from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.00s M language             from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.00s M ls                   from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.00s M mother               from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.00s M mother_object_type   from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.00s M nametype             from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.00s M nme                  from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.00s M nu                   from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.00s M number               from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.00s M otext                from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.00s M pargr                from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.00s M pdp                  from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.00s M pfm                  from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.00s M prs                  from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.00s M prs_gn               from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.00s M prs_nu               from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.00s M prs_ps               from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.00s M ps                   from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.00s M rank_lex             from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.00s M rank_occ             from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.00s M rela                 from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.00s M root                 from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.00s M sp                   from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.00s M st                   from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.00s M tab                  from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.00s M txt                  from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.00s M typ                  from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.00s M uvf                  from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.00s M vbe                  from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.00s M vbs                  from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.00s M voc_lex              from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.00s M voc_lex_utf8         from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.00s M vs                   from C:/Users/Martijn/github/bhsa/tf/c
#    |     0.00s M vt                   from C:/Users/Martijn/github/bhsa/tf/c

# %%
SKIP_LETT = set(' /=[_')

def text_per_verse():
    '''
    verse_dict is dict, keys are versenames(book_chapter_verse), values are concatenation of lexemes, each separated by _.
    letter_count_dict is dict, keys are letters, values are counts in whole Hebrew Bible.
    '''
    letter_count_dict = collections.defaultdict(int)
    skip_lett = SKIP_LETT
    for verse in F.otype.s('verse'):
        text = ''
        words = L.d(verse, 'word')
        for word in words:
            lexeme = F.lex.v(word)
            for lett in lexeme:
                if lett not in skip_lett:
                    text += lett
                    letter_count_dict[lett] += 1

    return(letter_count_dict)

# %%
def make_short_str(lexem, letter_count_dict):
    '''
    short_word is string 
    '''
    word_lett_dict = {}
    if len(lexem) <= 2:
        return(lexem)
    else:
        for lett in lexem:
            word_lett_dict[lett] = letter_count_dict[lett]
        lowest = min(word_lett_dict, key=word_lett_dict.get)  
        word_lett_dict.pop(lowest, None)
        lowest2 = min(word_lett_dict, key=word_lett_dict.get)

        low_set = {lowest, lowest2}
        short_word = ''
        for lett in lexem:
            if len(short_word) < 2:
                if lett in low_set:
                    short_word += lett
                    low_set.remove(lett)
                    
    return(short_word)

# %%
def make_num_dict(letter_count_dict):
    '''
    number_dict is dict, key is one or two letter string (there are (23*23 + 23) keys), value is numerical code of that string
    '''
    number_dict = {}
    basic_num = 100
    for letter in letter_count_dict.keys():
        feat = letter
        number_dict[feat] = basic_num
        basic_num += 1
        for letter2 in letter_count_dict.keys():
        
            feat = letter + letter2
            number_dict[feat] = basic_num
            basic_num += 1
    
    return(number_dict)

# %%
def make_skip_grams(number_dict):
    '''
    five_sam is list of reduced words.
    sam_order is int, it is place of last word of skipgram in MT.
    skip_grams_in_book is dict, key is place, value is list of skip-grams associated with it.
    skips_and_info is dict, key is place (int), value is string: book_chapter_verse
    sam_dict is dict, first key is numerical code of first word in skip-gram, second key is tuple of next words in skip-gram, 
    value is list of places of skip_gram in Hebrew Bible, place is place of last word in skip-gram
    
    '''
    sam_dict = collections.defaultdict(lambda: collections.defaultdict(list))
    skip_grams_in_book = collections.defaultdict(list)
    skips_and_info = {}
    order_list = []
    five_sam = []
    sam_order = 0
    skip_lett = SKIP_LETT
    
    for word in F.otype.s('word'):
        sam_order += 1
        where = T.sectionFromNode(word)
        info = where[0] + '_' + str(where[1]) + '_' + str(where[2])

        lexeme = F.lex.v(word)
        redu_lex = ''
        for lett in lexeme:
            if not lett in skip_lett:
                redu_lex += lett
        reduced = make_short_str(redu_lex, B)
        if len(five_sam) < 5:                
            five_sam.append(reduced)
        if len(five_sam) == 5:
            numb = [number_dict[word] for word in five_sam]
            numb0 = numb[0]
            sn1 = ''.join(str(numb[x]) for x in (1,2,3))
            sn2 = ''.join(str(numb[x]) for x in (1,2,4))
            sn3 = ''.join(str(numb[x]) for x in (1,3,4))
            sn4 = ''.join(str(numb[x]) for x in (2,3,4))
            sam_dict[numb0][sn1].append(sam_order)
            sam_dict[numb0][sn2].append(sam_order)
            sam_dict[numb0][sn3].append(sam_order)
            sam_dict[numb0][sn4].append(sam_order)
                
            skips_and_info[sam_order] = info
            del(five_sam[0])
    return(skips_and_info, sam_dict)

# %%
def make_grambi_dict(sam_dict):
    '''
    grambi_dict is dict, key is place(int), value is list of other places sharing skip-gram with place 
    grambi_list is list of all places (int)
    '''
    grambi_dict = collections.defaultdict(list)
    grambi_set = set()
    for key in sam_dict.keys():
        for key2 in sam_dict[key].keys():
            for place in sam_dict[key][key2]:
                grambi_set.add(place)
                for other_item in sam_dict[key][key2]:
                    if not other_item in grambi_dict[place]:
                        grambi_dict[place].append(other_item)
    grambi_list = sorted(list(grambi_set))
    return(grambi_dict, grambi_list)

# %%
def find_clusters(grambi_dict, grambi_list, chap_dict, paral_size): #=HK, KL, FG
    '''
    cluster_dict is dict in which clusters grow. Its keys are tuples, consisting of two parallel skipgrams.  
    if cluster is finished it moves to finished clusters. 
    '''
    finished_clusters = collections.defaultdict(list)
    #cluster_dict = collections.defaultdict(list)
    cluster_dict = collections.defaultdict(lambda: collections.defaultdict(list))
    start_skip_list = []
    for gram in grambi_list:
        if len(cluster_dict) == 0:
            if len(grambi_dict[gram]) > 1:
                for item in grambi_dict[gram]:
                    if item != gram:
                        if abs(item - gram) > paral_size:
                            if not (chap_dict[gram][0], chap_dict[gram][1]) == (chap_dict[item][0], chap_dict[item][1]):
                                if not set((chap_dict[gram], chap_dict[item])) in start_skip_list:
                                    cluster_dict[(gram, item)][gram].append(gram)
                                    cluster_dict[(gram, item)][item].append(item)
        else:
            keys = list(cluster_dict.keys())
            for it1, it2 in keys:
                match = False
                for probeer in range(6):
                    for keit in range(6):
                        if (gram + probeer) in grambi_dict[cluster_dict[(it1, it2)][it2][-1] + 1 + keit]:
                            match = True
                if match:
                    cluster_dict[(it1, it2)][it1].append(gram)
                    cluster_dict[(it1, it2)][it2].append(cluster_dict[(it1, it2)][it2][-1] + 1)
                    
                else:
                    if len(cluster_dict[(it1, it2)][it1]) > paral_size:
                        length = len(cluster_dict[(it1, it2)][it1])
                        finished_clusters[(it1, it2)] = cluster_dict[(it1, it2)]
                        start_skip_list.append(set((chap_dict[it1], chap_dict[it2])))
                        cluster_dict.pop((it1, it2))
                        print(chap_dict[it1], chap_dict[it2], length)
                    else:
                        cluster_dict.pop((it1, it2))

    return(finished_clusters)

# %% [markdown]
# In the following the cell the preprocessing of the data is done.

# %%
start_time = time.time()
B = text_per_verse()
D = make_num_dict(B)
FG, GH = make_skip_grams(D)
HK, KL = make_grambi_dict(GH)

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 27.647458791732788 seconds ---

# %% [markdown]
# In the next cell the parallel texts are detected.

# %%
start_time = time.time()
LM = find_clusters(HK, KL, FG, 30)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Genesis_10_6 1_Chronicles_1_8 38
# Genesis_10_13 1_Chronicles_1_11 70
# Genesis_10_22 1_Chronicles_1_17 93
# Genesis_36_32 1_Chronicles_1_43 95
# Exodus_20_2 Deuteronomy_5_6 112
# Leviticus_11_15 Deuteronomy_14_14 42
# Numbers_21_33 Deuteronomy_3_1 55
# Deuteronomy_3_2 Numbers_21_34 36
# Deuteronomy_5_7 Exodus_20_3 101
# Deuteronomy_14_15 Leviticus_11_16 36
# Joshua_15_15 Judges_1_11 34
# Joshua_15_17 Judges_1_13 54
# Joshua_21_6 1_Chronicles_6_47 41
# Joshua_21_13 1_Chronicles_6_42 47
# Joshua_21_20 1_Chronicles_6_51 41
# Joshua_21_27 1_Chronicles_6_56 36
# Judges_1_14 Joshua_15_18 47
# 2_Samuel_5_1 1_Chronicles_11_1 55
# 2_Samuel_5_14 1_Chronicles_14_4 44
# 2_Samuel_6_8 1_Chronicles_13_11 37
# 2_Samuel_7_4 1_Chronicles_17_3 36
# 2_Samuel_7_7 1_Chronicles_17_6 89
# 2_Samuel_7_10 1_Chronicles_17_9 34
# 2_Samuel_7_12 1_Chronicles_17_11 31
# 2_Samuel_7_16 1_Chronicles_17_14 48
# 2_Samuel_7_22 1_Chronicles_17_20 33
# 2_Samuel_7_24 1_Chronicles_17_22 62
# 2_Samuel_8_3 1_Chronicles_18_3 101
# 2_Samuel_8_11 1_Chronicles_18_11 34
# 2_Samuel_8_14 1_Chronicles_18_13 31
# 2_Samuel_8_15 1_Chronicles_18_14 45
# 2_Samuel_10_9 1_Chronicles_19_10 56
# 2_Samuel_12_30 1_Chronicles_20_2 44
# 2_Samuel_21_19 1_Chronicles_20_5 41
# 2_Samuel_22_4 Psalms_18_4 35
# 2_Samuel_22_8 Psalms_18_8 58
# 2_Samuel_22_16 Psalms_18_16 102
# 2_Samuel_22_28 Psalms_18_28 45
# 2_Samuel_22_33 Psalms_18_33 86
# 2_Samuel_22_49 Psalms_18_49 33
# 2_Samuel_23_11 1_Chronicles_11_13 33
# 2_Samuel_23_13 1_Chronicles_11_15 82
# 2_Samuel_23_17 1_Chronicles_11_19 89
# 2_Samuel_23_21 1_Chronicles_11_23 42
# 2_Samuel_23_26 1_Chronicles_11_28 45
# 2_Samuel_24_21 1_Chronicles_21_22 38
# 1_Kings_7_23 2_Chronicles_4_2 97
# 1_Kings_7_39 2_Chronicles_4_10 39
# 1_Kings_7_41 2_Chronicles_4_12 96
# 1_Kings_7_49 2_Chronicles_4_20 31
# 1_Kings_7_50 2_Chronicles_4_22 47
# 1_Kings_8_3 2_Chronicles_5_4 85
# 1_Kings_8_6 2_Chronicles_5_7 60
# 1_Kings_8_11 2_Chronicles_5_14 31
# 1_Kings_8_13 2_Chronicles_6_2 78
# 1_Kings_8_17 2_Chronicles_6_7 84
# 1_Kings_8_23 2_Chronicles_6_14 253
# 1_Kings_8_33 2_Chronicles_6_24 130
# 1_Kings_8_38 2_Chronicles_6_29 61
# 1_Kings_8_42 2_Chronicles_6_32 68
# 1_Kings_8_44 2_Chronicles_6_34 129
# 1_Kings_9_7 2_Chronicles_7_20 80
# 1_Kings_9_19 2_Chronicles_8_6 40
# 1_Kings_10_2 2_Chronicles_9_1 33
# 1_Kings_10_4 2_Chronicles_9_3 74
# 1_Kings_10_16 2_Chronicles_9_15 46
# 1_Kings_10_19 2_Chronicles_9_18 66
# 1_Kings_10_22 2_Chronicles_9_21 72
# 1_Kings_10_26 2_Chronicles_1_14 64
# 1_Kings_10_29 2_Chronicles_1_17 31
# 1_Kings_11_42 2_Chronicles_9_30 146
# 1_Kings_12_7 2_Chronicles_10_7 76
# 1_Kings_12_10 2_Chronicles_10_10 44
# 1_Kings_12_11 2_Chronicles_10_11 36
# 1_Kings_12_15 2_Chronicles_10_15 109
# 1_Kings_14_21 2_Chronicles_12_13 31
# 1_Kings_14_26 2_Chronicles_12_9 66
# 1_Kings_15_18 2_Chronicles_16_2 61
# 1_Kings_16_5 2_Kings_13_8 31
# 1_Kings_22_5 2_Chronicles_18_4 83
# 1_Kings_22_8 2_Chronicles_18_7 35
# 1_Kings_22_10 2_Chronicles_18_9 124
# 1_Kings_22_16 2_Chronicles_18_15 312
# 1_Kings_22_31 2_Chronicles_18_30 38
# 1_Kings_22_31 2_Chronicles_18_30 38
# 1_Kings_22_33 2_Chronicles_18_32 65
# 2_Kings_18_18 Isaiah_36_3 121
# 2_Kings_18_22 Isaiah_36_8 71
# 2_Kings_18_26 Isaiah_36_11 96
# 2_Kings_18_29 Isaiah_36_15 68
# 2_Kings_18_32 Isaiah_36_18 141
# 2_Kings_19_3 Isaiah_37_3 247
# 2_Kings_19_15 Isaiah_37_16 396
# 2_Kings_19_35 Isaiah_37_36 132
# 2_Kings_20_12 Isaiah_39_1 180
# 2_Kings_24_18 Jeremiah_52_1 107
# 2_Kings_25_4 Jeremiah_52_7 51
# 2_Kings_25_9 Jeremiah_52_13 36
# 2_Kings_25_11 Jeremiah_52_15 83
# 2_Kings_25_18 Jeremiah_52_24 104
# 2_Kings_25_27 Jeremiah_52_31 31
# 2_Kings_25_28 Jeremiah_52_32 35
# Isaiah_2_3 Micah_4_2 34
# Isaiah_36_4 2_Kings_18_19 103
# Isaiah_36_8 2_Kings_18_23 140
# Isaiah_36_13 2_Kings_18_28 88
# Isaiah_36_18 2_Kings_18_33 49
# Isaiah_36_21 2_Kings_18_36 82
# Isaiah_37_4 2_Kings_19_4 225
# Isaiah_37_17 2_Kings_19_16 370
# Isaiah_37_37 2_Kings_19_36 113
# Isaiah_39_1 2_Kings_20_13 166
# Jeremiah_52_1 2_Kings_23_36 31
# Jeremiah_52_3 2_Kings_24_20 75
# Jeremiah_52_16 2_Kings_25_12 59
# Jeremiah_52_25 2_Kings_25_19 85
# Jeremiah_52_33 2_Kings_25_29 32
# Psalms_18_9 2_Samuel_22_9 45
# Psalms_18_17 2_Samuel_22_17 96
# Psalms_18_29 2_Samuel_22_28 41
# Psalms_18_34 2_Samuel_22_34 85
# Psalms_96_2 1_Chronicles_16_23 78
# Psalms_105_1 1_Chronicles_16_8 126
# Psalms_106_47 1_Chronicles_16_35 32
# Ezra_1_1 2_Chronicles_36_22 67
# Ezra_2_1 Nehemiah_7_6 127
# Ezra_2_23 Nehemiah_7_27 67
# Ezra_2_35 Nehemiah_7_38 42
# Ezra_2_43 Nehemiah_7_46 45
# Ezra_2_50 Nehemiah_7_52 184
# Nehemiah_7_7 Ezra_2_2 61
# Nehemiah_7_13 Ezra_2_8 68
# Nehemiah_7_29 Ezra_2_25 57
# Nehemiah_7_39 Ezra_2_36 36
# Nehemiah_7_47 Ezra_2_44 37
# Nehemiah_7_53 Ezra_2_51 179
# 1_Chronicles_1_9 Genesis_10_6 32
# 1_Chronicles_1_12 Genesis_10_14 54
# 1_Chronicles_1_17 Genesis_10_23 84
# 1_Chronicles_1_44 Genesis_36_33 92
# 1_Chronicles_6_46 Joshua_21_5 48
# 1_Chronicles_6_52 Joshua_21_21 33
# 1_Chronicles_11_2 2_Samuel_5_2 63
# 1_Chronicles_11_16 2_Samuel_23_14 74
# 1_Chronicles_11_20 2_Samuel_23_18 80
# 1_Chronicles_11_28 2_Samuel_23_27 41
# 1_Chronicles_14_5 2_Samuel_5_14 39
# 1_Chronicles_16_9 Psalms_105_2 117
# 1_Chronicles_16_24 Psalms_96_3 74
# 1_Chronicles_17_7 2_Samuel_7_8 92
# 1_Chronicles_17_15 2_Samuel_7_17 47
# 1_Chronicles_17_23 2_Samuel_7_25 49
# 1_Chronicles_18_4 2_Samuel_8_4 94
# 1_Chronicles_18_10 2_Samuel_8_10 41
# 1_Chronicles_18_15 2_Samuel_8_16 38
# 1_Chronicles_19_9 2_Samuel_10_8 60
# 1_Chronicles_20_6 2_Samuel_21_20 37
# 1_Chronicles_21_12 2_Samuel_24_13 31
# 1_Chronicles_21_23 2_Samuel_24_22 34
# 2_Chronicles_1_15 1_Kings_10_27 36
# 2_Chronicles_4_3 1_Kings_7_24 72
# 2_Chronicles_4_13 1_Kings_7_42 66
# 2_Chronicles_5_1 1_Kings_7_51 35
# 2_Chronicles_5_3 1_Kings_8_2 92
# 2_Chronicles_5_8 1_Kings_8_7 52
# 2_Chronicles_6_1 1_Kings_8_12 88
# 2_Chronicles_6_6 1_Kings_8_16 96
# 2_Chronicles_6_15 1_Kings_8_24 242
# 2_Chronicles_6_25 1_Kings_8_34 114
# 2_Chronicles_6_33 1_Kings_8_43 58
# 2_Chronicles_6_35 1_Kings_8_45 121
# 2_Chronicles_7_21 1_Kings_9_8 74
# 2_Chronicles_9_4 1_Kings_10_5 59
# 2_Chronicles_9_12 1_Kings_10_13 33
# 2_Chronicles_9_16 1_Kings_10_17 33
# 2_Chronicles_9_19 1_Kings_10_20 50
# 2_Chronicles_9_22 1_Kings_10_23 56
# 2_Chronicles_9_31 1_Kings_11_43 140
# 2_Chronicles_10_8 1_Kings_12_8 105
# 2_Chronicles_10_12 1_Kings_12_12 32
# 2_Chronicles_10_16 1_Kings_12_16 100
# 2_Chronicles_12_9 1_Kings_14_25 70
# 2_Chronicles_16_3 1_Kings_15_19 58
# 2_Chronicles_18_5 1_Kings_22_6 73
# 2_Chronicles_18_8 1_Kings_22_9 119
# 2_Chronicles_18_13 1_Kings_22_14 34
# 2_Chronicles_18_16 1_Kings_22_17 299
# 2_Chronicles_18_33 1_Kings_22_34 53
# 2_Chronicles_20_31 1_Kings_22_42 43
# 2_Chronicles_36_23 Ezra_1_2 37
# --- 41.41999626159668 seconds ---
